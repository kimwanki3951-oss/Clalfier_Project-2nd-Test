# %% [markdown]
# <a href="https://colab.research.google.com/github/kimwanki3951-oss/Classification_Project-2nd-Test/blob/main/260720_DVC_Using_Test_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 안녕하세요
# ---

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
#Github의 Project Token 입력 (Public의 경우 안 해도 됨.)
from getpass import getpass

github_token = getpass("GitHub Personal Access Token: ")
# Out:
# GitHub Personal Access Token: ··········

# %%
#Github Clone 만들기 (Public의 경우 안 해도 됨.)
# !git clone -b main https://github.com/kimwanki3951-oss/Classification_Project-2nd-Test.git
# Out:
# Cloning into 'Clalfier_Project-2nd-Test'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 44 (delta 13), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (44/44), 20.27 KiB | 6.76 MiB/s, done.
# Resolving deltas: 100% (13/13), done.

# %%
# %cd /content/Classification_Project-2nd-Test
# Out:
# /content/Clalfier_Project-2nd-Test

# %%
# !ls -la
# Out:
# total 52
# drwxr-xr-x 5 root root  4096 Jul 20 11:06  .
# drwxr-xr-x 1 root root  4096 Jul 20 11:06  ..
# -rw-r--r-- 1 root root  1674 Jul 20 11:06  Common_Dataset_DVC_Pipeline.ipynb
# drwxr-xr-x 2 root root  4096 Jul 20 11:06 '. dvc'
# -rw-r--r-- 1 root root   394 Jul 20 11:06  dvc.yaml
# drwxr-xr-x 8 root root  4096 Jul 20 11:06  .git
# -rw-r--r-- 1 root root   237 Jul 20 11:06  params.yaml
# -rw-r--r-- 1 root root  1344 Jul 20 11:06  README.md
# -rw-r--r-- 1 root root    91 Jul 20 11:06  requirements.txt
# -rw-r--r-- 1 root root 11785 Jul 20 11:06  run_pipeline.py
# drwxr-xr-x 4 root root  4096 Jul 20 11:06  src

# %%
# !pip install pyyaml

# %%
# !pip install -q -r requirements.txt
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.3/79.3 kB 9.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 451.2/451.2 kB 26.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.5/155.5 kB 16.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.2/214.2 kB 21.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.1/118.1 kB 15.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.2/74.2 kB 8.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 67.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 470.1/470.1 kB 39.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 5.6 MB/s eta 0:00:00
# ...

# %%
# !dvc version
# Out:
# DVC version: 3.67.1 (pip)
# -------------------------
# Platform: Python 3.12.13 on Linux-6.6.122+-x86_64-with-glibc2.35
# Subprojects:
# 	dvc_data = 3.18.3
# 	dvc_objects = 5.2.0
# 	dvc_render = 1.0.2
# 	dvc_task = 0.40.2
# 	scmrepo = 3.6.2
# Supports:
# 	gdrive (pydrive2 = 1.21.1),
# 	http (aiohttp = 3.14.1, aiohttp-retry = 2.9.1),
# 	https (aiohttp = 3.14.1, aiohttp-retry = 2.9.1)
# Config:
# 	Global: /root/.config/dvc
# 	System: /etc/xdg/dvc

# %%
# !python run_pipeline.py
# Out:
# [DRIVE] Google Drive detected: /content/drive/MyDrive
# [DVC] Initializing DVC repository.
#
# ...
# [RUN] dvc init
# ...
# Initialized DVC repository.
#
# You can now commit the changes to git.
#
# +---------------------------------------------------------------------+
# |                                                                     |
# |        DVC has enabled anonymous aggregate usage analytics.         |
# |     Read the analytics documentation (and how to opt-out) here:     |
# |             <https://dvc.org/doc/user-guide/analytics>              |
# |                                                                     |
# +---------------------------------------------------------------------+
#
# What's next?
# ------------
# - Check out the documentation: <https://dvc.org/doc>
# - Get help and share ideas: <https://dvc.org/chat>
# - Star us on GitHub: <https://github.com/treeverse/dvc>
#
# ...
# [RUN] dvc repro
# ...
# Running stage 'download':
# > python src/data/download.py
# ...
